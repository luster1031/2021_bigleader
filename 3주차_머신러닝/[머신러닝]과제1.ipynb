# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매'

# %%
df2 = pd.read_csv('연립다세대(매매)__실거래가_2012.csv',header=15, encoding='CP949')
df3 = pd.read_csv('연립다세대(매매)__실거래가_2013.csv',header=15, encoding='CP949')
df4 = pd.read_csv('연립다세대(매매)__실거래가_2014.csv',header=15, encoding='CP949')
df5 = pd.read_csv('연립다세대(매매)__실거래가_2015.csv',header=15, encoding='CP949')
df6 = pd.read_csv('연립다세대(매매)__실거래가_2016.csv',header=15, encoding='CP949')
df7 = pd.read_csv('연립다세대(매매)__실거래가_2017.csv',header=15, encoding='CP949')
df8 = pd.read_csv('연립다세대(매매)__실거래가_2018.csv',header=15, encoding='CP949')
df9 = pd.read_csv('연립다세대(매매)__실거래가_2019.csv',header=15, encoding='CP949')
df10 = pd.read_csv('연립다세대(매매)__실거래가_2020.csv',header=15, encoding='CP949')
df11= pd.read_csv('연립다세대(매매)__실거래가_2021.csv',header=15, encoding='CP949')
df11= pd.read_csv('연립다세대(매매)__실거래가_2011.csv',header=15, encoding='CP949')

# %%
df1['건물명'].unique()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# pairplot
#sns.pairplot(df1)

# %%
local_map = {}
for i, loc in enumerate(df1['시군구'].unique()):
    local_map[loc] = i

# %%
local_map

# %%
df1['시군구'] = df1['시군구'].map(local_map)
df1

# %%
local_map = {}
for i, loc in enumerate(df1['도로명'].unique()):
    local_map[loc] = i
df1['도로명'] = df1['도로명'].map(local_map)
df1

# %%
## seaborn
from matplotlib import font_manager, rc 
import seaborn as sns
plt.rcParams['axes.unicode_minus']=False
path='c:/Windows/Fonts/malgun.ttf' 
font_name=font_manager.FontProperties(fname=path).get_name() 
rc('font',family=font_name)

# %%
# the features와 response의 관계를 scatterplot으로 그리기
sns.pairplot(df1, x_vars=['건축년도','전용면적(㎡)','대지권면적(㎡)'], y_vars='거래금액(만원)' ,
             size=7, aspect=0.7, kind='scatter')

# %%
# the features와 response의 관계를 scatterplot으로 그리기
sns.pairplot(df1, x_vars=['시군구','도로명','지역'], y_vars='거래금액(만원)' ,
             size=7, aspect=0.7, kind='scatter')

# %%
import pandas as pd
import glob
import os

# %%
input_file = r'C:\Users\limhanna\Desktop\4 머신러닝\02_Regression\data\서울_연립다세대_매매'
output_file = r'C:\Users\limhanna\Desktop\4 머신러닝\02_Regression\data\서울_연립다세대_매매\result.csv'

allfile_list = glob.glob(os.path.join(input_file, '연립다세대(매매)__실거래가_*'))

# %%
print(allfile_list)
# Out:
# ['C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2010.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2011.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2012.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2013.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2014.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2015.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2016.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2017.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2018.csv', 'C:\\Users\\limhanna\\Desktop\\4 머신러닝\\02_Regression\\data\\서울_연립다세대_매매\\연립다세대(매매)__실거래가_2019.csv
# ...

# %%
allData = []
for file in allfile_list:
    df = pd.read_csv(file,header=15, encoding='CP949')
    allData.append(df)

# %%
dataCombine = pd.concat(allData, axis = 0,ignore_index = True)

# %%
dataCombine
# Out:
#                   시군구       번지    본번  부번           건물명  전용면적(㎡)  대지권면적(㎡)  \
# 0       서울특별시 강남구 개포동   170-18   170  18      (170-18)    26.60     21.53
# 1       서울특별시 강남구 개포동  1219-11  1219  11         강남하이츠    39.90     19.33
# 2       서울특별시 강남구 개포동   1202-2  1202   2         경모하이츠    51.69     21.20
# 3       서울특별시 강남구 개포동  1235-16  1235  16          광현빌라    62.76     34.53
# 4       서울특별시 강남구 개포동  1235-16  1235  16          광현빌라    77.34     42.55
# ...               ...      ...   ...  ..           ...      ...       ...
# 493350  서울특별시 중랑구 중화동     86-9    86   9   화수분빌리지(105)    55.58     27.57
# 493351  서울특별시 중랑구 중화동    307-4   307   4  화인하우스(307-4)    54.32     27.24
# 493352  서울특별시 중랑구 중화동    307-4   307   4  화인하우스(307-4)    56.51     28.34
# 493353  서울특별시 중랑구 중화동     15-2    15   2          휴렉스빌    29.44     18.14
# 493354  서울특별시 중랑구 중화동     15-2    15   2          휴렉스빌    29.27     18.14
#
#           계약년월  계약일 거래금액(만원)  층    건축년도           도로명  해제사유발생일
# ...

# %%
dataCombine.shape
# Out:
# (493355, 14)

# %%
sns.pairplot(dataCombine)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# the features와 response의 관계를 scatterplot으로 그리기
sns.pairplot(df1, x_vars=['시군구','도로명','지역'], y_vars='거래금액(만원)' ,
             size=7, aspect=0.7, kind='scatter')

# %%
local_map = {}
for i, loc in enumerate(dataCombine['도로명'].unique()):
    local_map[loc] = i
dataCombine['도로명'] = dataCombine['도로명'].map(local_map)
dataCombine
# Out:
#                   시군구       번지    본번  부번           건물명  전용면적(㎡)  대지권면적(㎡)  \
# 0       서울특별시 강남구 개포동   170-18   170  18      (170-18)    26.60     21.53
# 1       서울특별시 강남구 개포동  1219-11  1219  11         강남하이츠    39.90     19.33
# 2       서울특별시 강남구 개포동   1202-2  1202   2         경모하이츠    51.69     21.20
# 3       서울특별시 강남구 개포동  1235-16  1235  16          광현빌라    62.76     34.53
# 4       서울특별시 강남구 개포동  1235-16  1235  16          광현빌라    77.34     42.55
# ...               ...      ...   ...  ..           ...      ...       ...
# 493350  서울특별시 중랑구 중화동     86-9    86   9   화수분빌리지(105)    55.58     27.57
# 493351  서울특별시 중랑구 중화동    307-4   307   4  화인하우스(307-4)    54.32     27.24
# 493352  서울특별시 중랑구 중화동    307-4   307   4  화인하우스(307-4)    56.51     28.34
# 493353  서울특별시 중랑구 중화동     15-2    15   2          휴렉스빌    29.44     18.14
# 493354  서울특별시 중랑구 중화동     15-2    15   2          휴렉스빌    29.27     18.14
#
#           계약년월  계약일 거래금액(만원)  층    건축년도    도로명  해제사유발생일
# ...

# %%
local_map = {}
for i, loc in enumerate(dataCombine['시군구'].unique()):
    local_map[loc] = i
dataCombine['시군구'] = dataCombine['시군구'].map(local_map)
dataCombine
# Out:
#         시군구       번지    본번  부번           건물명  전용면적(㎡)  대지권면적(㎡)    계약년월  계약일  \
# 0         0   170-18   170  18      (170-18)    26.60     21.53  201007   13
# 1         0  1219-11  1219  11         강남하이츠    39.90     19.33  201001   22
# 2         0   1202-2  1202   2         경모하이츠    51.69     21.20  201003   12
# 3         0  1235-16  1235  16          광현빌라    62.76     34.53  201001   22
# 4         0  1235-16  1235  16          광현빌라    77.34     42.55  201011    2
# ...     ...      ...   ...  ..           ...      ...       ...     ...  ...
# 493350  286     86-9    86   9   화수분빌리지(105)    55.58     27.57  202103    4
# 493351  286    307-4   307   4  화인하우스(307-4)    54.32     27.24  202102   17
# 493352  286    307-4   307   4  화인하우스(307-4)    56.51     28.34  202102   19
# 493353  286     15-2    15   2          휴렉스빌    29.44     18.14  202104    6
# 493354  286     15-2    15   2          휴렉스빌    29.27     18.14  202106    8
#
#        거래금액(만원)  층    건축년도    도로명  해제사유발생일
# ...

# %%
local_map = {}
for i, loc in enumerate(dataCombine['건물명'].unique()):
    local_map[loc] = i
dataCombine['건물명'] = dataCombine['건물명'].map(local_map)
dataCombine
# Out:
#         시군구       번지    본번  부번    건물명  전용면적(㎡)  대지권면적(㎡)    계약년월  계약일  \
# 0         0   170-18   170  18      0    26.60     21.53  201007   13
# 1         0  1219-11  1219  11      1    39.90     19.33  201001   22
# 2         0   1202-2  1202   2      2    51.69     21.20  201003   12
# 3         0  1235-16  1235  16      3    62.76     34.53  201001   22
# 4         0  1235-16  1235  16      3    77.34     42.55  201011    2
# ...     ...      ...   ...  ..    ...      ...       ...     ...  ...
# 493350  286     86-9    86   9  44002    55.58     27.57  202103    4
# 493351  286    307-4   307   4  51743    54.32     27.24  202102   17
# 493352  286    307-4   307   4  51743    56.51     28.34  202102   19
# 493353  286     15-2    15   2  48583    29.44     18.14  202104    6
# 493354  286     15-2    15   2  48583    29.27     18.14  202106    8
#
#        거래금액(만원)  층    건축년도    도로명  해제사유발생일
# 0        29,350  1  1988.0      0      NaN
# ...

# %%
# the features와 response의 관계를 scatterplot으로 그리기
#sns.pairplot(dataCombine, x_vars=['시군구','번지','본번'], y_vars='거래금액(만원)' ,
#             size=7, aspect=0.7, kind='scatter')

# %%
# the features와 response의 관계를 scatterplot으로 그리기
#sns.pairplot(dataCombine, x_vars=['부번','건물명','전용면적(㎡)'], y_vars='거래금액(만원)' ,
#             size=7, aspect=0.7, kind='scatter')

# %%
# the features와 response의 관계를 scatterplot으로 그리기
#sns.pairplot(dataCombine, x_vars=['대지권면적(㎡)','계약년월','계약일'], y_vars='거래금액(만원)' ,
#             size=7, aspect=0.7, kind='scatter')

# %%
# the features와 response의 관계를 scatterplot으로 그리기
#sns.pairplot(dataCombine, x_vars=['거래금액(만원)','층','건축년도'], y_vars='거래금액(만원)' ,
#             size=7, aspect=0.7, kind='scatter')

# %%
# the features와 response의 관계를 scatterplot으로 그리기
#sns.pairplot(dataCombine, x_vars=['도로명'], y_vars='거래금액(만원)' ,
#             size=7, aspect=0.7, kind='scatter')

# %%
dataCombine['거래금액(만원)'] = dataCombine['거래금액(만원)'].apply(lambda x : x.replace(',',''))
dataCombine['거래금액(만원)'] = dataCombine['거래금액(만원)'].astype(int)

# %%
'''import matplotlib.pyplot as plt
import numpy as np
X = dataCombine['부번'] # advertising['TV']
Y = dataCombine['거래금액(만원)'] # advertising['Sales']

# X, Y의 평균을 구합니다.
x_bar = sum(X) / len(X)
y_bar = sum(Y) / len(Y)

# 최소제곱법으로 a, b를 구합니다.
a = sum([(y - y_bar) * (x - x_bar) for y, x in list(zip(Y, X))])
a /= sum([(x - x_bar) ** 2 for x in X])
b = y_bar - a * x_bar
print('a:', a, 'b:', b)

# 그래프를 그리기 위해 회귀선의 x, y 데이터를 구합니다.
line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

# 붉은색 실선으로 회귀선을 그립니다.
plt.plot(line_x,line_y,'r-')

plt.plot(X,Y,'bo')
plt.xlabel('거래금액')
plt.ylabel('부번')
plt.show()'''

# %%
'''import matplotlib.pyplot as plt
import numpy as np
X = dataCombine['도로명'] # advertising['TV']
Y = dataCombine['거래금액(만원)'] # advertising['Sales']

# X, Y의 평균을 구합니다.
x_bar = sum(X) / len(X)
y_bar = sum(Y) / len(Y)

# 최소제곱법으로 a, b를 구합니다.
a = sum([(y - y_bar) * (x - x_bar) for y, x in list(zip(Y, X))])
a /= sum([(x - x_bar) ** 2 for x in X])
b = y_bar - a * x_bar
print('a:', a, 'b:', b)

# 그래프를 그리기 위해 회귀선의 x, y 데이터를 구합니다.
line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

# 붉은색 실선으로 회귀선을 그립니다.
plt.plot(line_x,line_y,'r-')

plt.plot(X,Y,'bo')
plt.xlabel('거래금액')
plt.ylabel('도로명')
plt.show()'''

# %%
'''import matplotlib.pyplot as plt
import numpy as np
X = dataCombine['층'] # advertising['TV']
Y = dataCombine['거래금액(만원)'] # advertising['Sales']

# X, Y의 평균을 구합니다.
x_bar = sum(X) / len(X)
y_bar = sum(Y) / len(Y)

# 최소제곱법으로 a, b를 구합니다.
a = sum([(y - y_bar) * (x - x_bar) for y, x in list(zip(Y, X))])
a /= sum([(x - x_bar) ** 2 for x in X])
b = y_bar - a * x_bar
print('a:', a, 'b:', b)

# 그래프를 그리기 위해 회귀선의 x, y 데이터를 구합니다.
line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

# 붉은색 실선으로 회귀선을 그립니다.
plt.plot(line_x,line_y,'r-')

plt.plot(X,Y,'bo')
plt.xlabel('거래금액')
plt.ylabel('층')
plt.show()'''

# %%
# feature variable to X
X = dataCombine[['본번','부번','전용면적(㎡)','계약년월','층','건축년도']]

# response target variable to y
Y = dataCombine['거래금액(만원)']

# %%
X.head()
# Out:
#      본번  부번  전용면적(㎡)    계약년월  층    건축년도
# 0   170  18    26.60  201007  1  1988.0
# 1  1219  11    39.90  201001  1  1993.0
# 2  1202   2    51.69  201003  1  1991.0
# 3  1235  16    62.76  201001  2  2001.0
# 4  1235  16    77.34  201011  4  2001.0

# %%
Y.head()
# Out:
# 0    29350
# 1    21500
# 2    28500
# 3    36500
# 4    44200
# Name: 거래금액(만원), dtype: int32

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.7 , random_state=100)

# %%
X_train
# Out:
#          본번   부번  전용면적(㎡)    계약년월  층    건축년도
# 113945  258   54    52.80  201408  2  1987.0
# 187825  950    7    66.86  201511  4  2002.0
# 17781    24    2    44.15  201008 -1  1993.0
# 421306  238  105    29.98  202007  2  2016.0
# 94699   625   17    59.73  201309  3  2001.0
# ...     ...  ...      ...     ... ..     ...
# 339799   66   86    53.92  201808  3  2001.0
# 253799   39   12    35.19  201603  2  1989.0
# 210755  963    9    13.60  201601  4  2011.0
# 56088   166  247    59.79  201103  2  1999.0
# 300552  447    2    51.60  201707  5  2014.0
#
# [345348 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
# LinearRegression lr(Creating LinearRegression Object)
lm = LinearRegression()

# %%
X_train.head()
# Out:
#          본번   부번  전용면적(㎡)    계약년월  층    건축년도
# 113945  258   54    52.80  201408  2  1987.0
# 187825  950    7    66.86  201511  4  2002.0
# 17781    24    2    44.15  201008 -1  1993.0
# 421306  238  105    29.98  202007  2  2016.0
# 94699   625   17    59.73  201309  3  2001.0

# %%
y_train.head()
# Out:
# 113945    12200
# 187825    21500
# 17781     13000
# 421306    19300
# 94699     16800
# Name: 거래금액(만원), dtype: int32

# %%
X_train['건축년도'].mean()
# Out:
# 2002.4531744537912

# %%
X_train['건축년도'].fillna(X_train['건축년도'].mean())
# Out:
# 113945    1987.0
# 187825    2002.0
# 17781     1993.0
# 421306    2016.0
# 94699     2001.0
#            ...
# 339799    2001.0
# 253799    1989.0
# 210755    2011.0
# 56088     1999.0
# 300552    2014.0
# Name: 건축년도, Length: 345348, dtype: float64

# %%
from catboost import CatBoostRegressor
cbc=CatBoostRegressor()
cbc.fit(X_train,y_train)
# Out:
# Learning rate set to 0.110461
# 0:	learn: 17603.5738043	total: 201ms	remaining: 3m 20s
# 1:	learn: 16837.5811946	total: 236ms	remaining: 1m 57s
# 2:	learn: 16183.5166168	total: 276ms	remaining: 1m 31s
# 3:	learn: 15625.3300809	total: 306ms	remaining: 1m 16s
# 4:	learn: 15160.9639533	total: 342ms	remaining: 1m 8s
# 5:	learn: 14754.9416180	total: 388ms	remaining: 1m 4s
# 6:	learn: 14428.3867739	total: 435ms	remaining: 1m 1s
# 7:	learn: 14116.6812660	total: 473ms	remaining: 58.6s
# 8:	learn: 13871.3097340	total: 506ms	remaining: 55.7s
# 9:	learn: 13647.3473883	total: 539ms	remaining: 53.3s
# 10:	learn: 13464.8770040	total: 567ms	remaining: 50.9s
# 11:	learn: 13296.4401717	total: 598ms	remaining: 49.2s
# 12:	learn: 13158.4956852	total: 642ms	remaining: 48.7s
# 13:	learn: 13042.2466023	total: 670ms	remaining: 47.2s
# 14:	learn: 12930.9605416	total: 699ms	remaining: 45.9s
# 15:	learn: 12841.0678496	total: 727ms	remaining: 44.7s
# 16:	learn: 12746.6448067	total: 759ms	remaining: 43.9s
# ...

# %%
# 예측을 위한 predictions on the testing set
y_pred = cbc.predict(X_test)

# %%
y_pred
# Out:
# array([19686.03983454, 19532.08794953, 21988.7309974 , ...,
#        14017.29018591, 16703.98375119, 18664.00530237])

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
#import matplotlib.pyplot as plt

c = [i for i in range(1, 148008, 1)]  # generating index 
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20) # Plot heading 
plt.xlabel('Index', fontsize=18)  # X-label
plt.ylabel('Sales', fontsize=16)   # Y-label
# Out:
# Text(0, 0.5, 'Sales')

# %%
c = [i for i in range(1,148008, 1)]
fig = plt.figure()
plt.plot(c,y_test-y_pred, color="blue", linewidth=2.5, linestyle="-")
fig.suptitle('Error Terms', fontsize=20) # Plot heading 
plt.xlabel('Index', fontsize=18)              # X-label
plt.ylabel('ytest-ypred', fontsize=16)    # Y-label
# Out:
# Text(0, 0.5, 'ytest-ypred')

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r_squared = r2_score(y_test, y_pred)

# %%
print('Mean_Asolute_Error:', mae)
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Asolute_Error: 5858.203030704899
# Mean_Squared_Error : 100572193.46496823
# r_square_value : 0.7075269021771515
